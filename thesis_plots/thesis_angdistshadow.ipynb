# %%
import numpy as np

# %matplotlib notebook
import matplotlib.pyplot as plt
import matplotlib as mpl
import healpy as hp

import sys
sys.path.append("../")
import GSHEWaveform

# %%
N = 50
k2 = np.linspace(-1, 1, N)
k3 = np.linspace(-1, 1, N)

k2, k3 = [x.reshape(-1, ) for x in np.meshgrid(k2, k3)]


m = (k2**2 + k3**2) <= 1
psi = np.arccos(k3)
rho = np.pi + np.arcsin(k2 / np.sqrt(1 - k3**2))

dist = np.asarray([hp.rotator.angdist([psi[i], rho[i]], [np.pi/2, np.pi])[0] for i in range(N**2)])
# Out:
# /var/folders/tc/scj1hsmn0gv36xfyx6hsk_g80000gn/T/ipykernel_88918/2138106164.py:10: RuntimeWarning: divide by zero encountered in true_divide
#   rho = np.pi + np.arcsin(k2 / np.sqrt(1 - k3**2))
# /var/folders/tc/scj1hsmn0gv36xfyx6hsk_g80000gn/T/ipykernel_88918/2138106164.py:10: RuntimeWarning: invalid value encountered in arcsin
#   rho = np.pi + np.arcsin(k2 / np.sqrt(1 - k3**2))

# %%
GSHEWaveform.setmplstyle("../plot_style.txt")
# GSHEWaveform.setmplstyle()

plt.figure()

plt.scatter(rho[m], psi[m], c=dist[m])

plt.xlabel(r"$\rho$")
plt.ylabel(r"$\psi$")



plt.savefig("/Users/richard/Downloads/shadow_coords.pdf", bbox_inches="tight", dpi=300)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="345">
